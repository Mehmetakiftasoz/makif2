# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehmetakiftasoz/makif2/blob/MAKIF_COLAB/ZMM059_birlestirveindir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
df_zmm059_2022 = pd.read_csv('/content/ZMM059 2022.csv', sep=None, engine='python')
df_zmm059_2023 = pd.read_csv('/content/ZMM059 2023.csv', sep=None, engine='python')
df_zmm059_2024_1 = pd.read_csv('/content/ZMM059 2024-1.csv', sep=None, engine='python')
df_zmm059_2024_2 = pd.read_csv('/content/ZMM059 2024-2.csv', sep=None, engine='python')
df_zmm059_2024_3 = pd.read_csv('/content/ZMM059 2024-3.csv', sep=None, engine='python')
df_zmm059_2024_4 = pd.read_csv('/content/ZMM059 2024-4.csv', sep=None, engine='python')
df_zmm059_2025 = pd.read_csv('/content/ZMM059 2025.csv', sep=None, engine='python')

# sep=None will automatically detect the delimiter
# engine='python' is slower but more robust for complex cases

# %%
# DataFrame'leri bir listeye topla
dfs = [df_zmm059_2022, df_zmm059_2023, df_zmm059_2024_1, df_zmm059_2024_2, df_zmm059_2024_3, df_zmm059_2024_4, df_zmm059_2025]

# Hepsini birleştir
df_zmm059_2022_2025 = pd.concat(dfs, ignore_index=True)
df_zmm059_2022_2025_ = pd.concat(dfs, ignore_index=True)
# Kontrol için ilk satırlara bak
print(df_zmm059_2022_2025.head(5))
# Out:
#    ﻿Документ закупки  Позиция Индикатор удаления неполн. Материал      Заявка  \
# 0                NaN        0                NaN     NaN      NaN  2200000571
# 1                NaN        0                NaN     NaN      NaN  2200000571
# 2                NaN        0                NaN     NaN      NaN  2200000571
# 3                NaN        0                NaN     NaN      NaN  2200000571
# 4                NaN        0                NaN     NaN      NaN  2200000571
#
#    Позиция заявки  Запрос  Позиция.1  Долгосрочный договор  ...  \
# 0            7420     NaN          0                   NaN  ...
# 1            7410     NaN          0                   NaN  ...
# 2            7430     NaN          0                   NaN  ...
# 3            7440     NaN          0                   NaN  ...
# 4            7450     NaN          0                   NaN  ...
#
#    Групповой номер  Телефон  Обозначение вида материал Группа закупок.2  \
# 0              NaN      NaN                        NaN              NaN
# 1              NaN      NaN                        NaN              NaN
# 2              NaN      NaN                        NaN              NaN
# 3              NaN      NaN                        NaN              NaN
# 4              NaN      NaN                        NaN              NaN
#
#   Название ГрЗакупок.2 Затребовал  Количество во Внутреннем заказе  \
# 0                  NaN        NaN                                0
# 1                  NaN        NaN                                0
# 2                  NaN        NaN                                0
# 3                  NaN        NaN                                0
# 4                  NaN        NaN                                0
#
#   Единица измерения № комиссии № ЗП в 1С
# 0               NaN        NaN      EBAN
# 1               NaN        NaN      EBAN
# 2               NaN        NaN      EBAN
# 3               NaN        NaN      EBAN
# 4               NaN        NaN      EBAN
#
# [5 rows x 104 columns]

# %%
df_zmm059_2022_2025["B3-B3POZ"] = (
    df_zmm059_2022_2025["Заявка"].astype(str) + "_" + df_zmm059_2022_2025["Позиция заявки"].astype(str)
)

# %%
df_zmm059_2022_2025.rename(columns={'﻿Документ закупки': 'Документ_закупки'}, inplace=True)
df_zmm059_2022_2025.columns.values[1] = "Зп_Поз"

# %%
print(df_zmm059_2022_2025.tail(5))
# Out:
#         Документ_закупки  Зп_Поз Индикатор удаления неполн.      Материал  \
# 601029      3.400013e+09      10                  L     NaN  4500187083.0
# 601030      3.400013e+09      20                  L     NaN  4500187083.0
# 601031      3.400013e+09      10                  L     NaN  4500187083.0
# 601032      4.500000e+09      10                  L     NaN  4500415852.0
# 601033      4.500000e+09      20                  L     NaN  4500415855.0
#
#             Заявка  Позиция заявки  Запрос  Позиция.1  Долгосрочный договор  \
# 601029  2100003304              10     NaN          0          4.600006e+09
# 601030  2100003304              10     NaN          0          4.600006e+09
# 601031  2100003304              10     NaN          0          4.600006e+09
# 601032  2100003682              10     NaN          0                   NaN
# 601033  2100003682              20     NaN          0                   NaN
#
#         ...  Телефон  Обозначение вида материал  Группа закупок.2  \
# 601029  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601030  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601031  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601032  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601033  ...      NaN  IC İnşaat Proje Malzemesi               NaN
#
#        Название ГрЗакупок.2 Затребовал Количество во Внутреннем заказе  \
# 601029                  NaN        NaN                           0,000
# 601030                  NaN        NaN                           0,000
# 601031                  NaN        NaN                           0,000
# 601032                  NaN        NaN                           0,000
# 601033                  NaN        NaN                           0,000
#
#         Единица измерения   № комиссии    № ЗП в 1С       B3-B3POZ
# 601029                NaN  AKNPMM-3135  AKNPMM-3135  2100003304_10
# 601030                NaN  AKNPMM-3135  AKNPMM-3135  2100003304_10
# 601031                NaN   PONPMM3135   AKNPMM3135  2100003304_10
# 601032                NaN   2100003654            .  2100003682_10
# 601033                NaN   2100003654            .  2100003682_20
#
# [5 rows x 105 columns]

# %%
df_zmm059_2022_2025["Документ_закупки"] = df_zmm059_2022_2025["Документ_закупки"].replace("", pd.NA)
df_zmm059_2022_2025["Зп_Поз"] = df_zmm059_2022_2025["Зп_Поз"].replace("", pd.NA)

# %%
adetler = df_zmm059_2022_2025["B3-B3POZ"].value_counts()

# %%
mukerrer_kodlar = adetler[adetler > 1].index

# %%
silinmesi_gerekenler = df_zmm059_2022_2025[
    (df_zmm059_2022_2025["B3-B3POZ"].isin(mukerrer_kodlar)) &
    (df_zmm059_2022_2025["Документ_закупки"].isna())

]

# %%
df_zmm059_2022_2025 = df_zmm059_2022_2025.drop(silinmesi_gerekenler.index)

# %%
print(f"Kalan satır sayısı: {len(df_zmm059_2022_2025)}")
# Out:
# Kalan satır sayısı: 364967

# %%
df_zmm059_2022_2025
# Out:
#         Документ_закупки  Зп_Поз Индикатор удаления неполн.      Материал  \
# 44                   NaN       0                NaN     NaN           NaN
# 45                   NaN       0                NaN     NaN           NaN
# 68                   NaN       0                NaN     NaN           NaN
# 69                   NaN       0                NaN     NaN           NaN
# 785                  NaN       0                NaN     NaN           NaN
# ...                  ...     ...                ...     ...           ...
# 601029      3.400013e+09      10                  L     NaN  4500187083.0
# 601030      3.400013e+09      20                  L     NaN  4500187083.0
# 601031      3.400013e+09      10                  L     NaN  4500187083.0
# 601032      4.500000e+09      10                  L     NaN  4500415852.0
# 601033      4.500000e+09      20                  L     NaN  4500415855.0
#
#             Заявка  Позиция заявки  Запрос  Позиция.1  Долгосрочный договор  \
# 44      2200000571            7790     NaN          0                   NaN
# 45      2200000571            7800     NaN          0                   NaN
# 68      2200000571            7590     NaN          0                   NaN
# 69      2200000571            7600     NaN          0                   NaN
# 785     2200000578            2320     NaN          0                   NaN
# ...            ...             ...     ...        ...                   ...
# 601029  2100003304              10     NaN          0          4.600006e+09
# 601030  2100003304              10     NaN          0          4.600006e+09
# 601031  2100003304              10     NaN          0          4.600006e+09
# 601032  2100003682              10     NaN          0                   NaN
# 601033  2100003682              20     NaN          0                   NaN
#
#         ...  Телефон  Обозначение вида материал  Группа закупок.2  \
# 44      ...      NaN                        NaN               NaN
# 45      ...      NaN                        NaN               NaN
# 68      ...      NaN                        NaN               NaN
# 69      ...      NaN                        NaN               NaN
# 785     ...      NaN                        NaN               NaN
# ...     ...      ...                        ...               ...
# 601029  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601030  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601031  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601032  ...      NaN  IC İnşaat Proje Malzemesi               NaN
# 601033  ...      NaN  IC İnşaat Proje Malzemesi               NaN
#
#        Название ГрЗакупок.2 Затребовал Количество во Внутреннем заказе  \
# 44                      NaN        NaN                               0
# 45                      NaN        NaN                               0
# 68                      NaN        NaN                               0
# 69                      NaN        NaN                               0
# 785                     NaN        NaN                               0
# ...                     ...        ...                             ...
# 601029                  NaN        NaN                           0,000
# 601030                  NaN        NaN                           0,000
# 601031                  NaN        NaN                           0,000
# 601032                  NaN        NaN                           0,000
# 601033                  NaN        NaN                           0,000
#
#         Единица измерения   № комиссии    № ЗП в 1С         B3-B3POZ
# 44                    NaN          NaN         EBAN  2200000571_7790
# 45                    NaN          NaN         EBAN  2200000571_7800
# 68                    NaN          NaN         EBAN  2200000571_7590
# 69                    NaN          NaN         EBAN  2200000571_7600
# 785                   NaN          NaN         EBAN  2200000578_2320
# ...                   ...          ...          ...              ...
# 601029                NaN  AKNPMM-3135  AKNPMM-3135    2100003304_10
# 601030                NaN  AKNPMM-3135  AKNPMM-3135    2100003304_10
# 601031                NaN   PONPMM3135   AKNPMM3135    2100003304_10
# 601032                NaN   2100003654            .    2100003682_10
# 601033                NaN   2100003654            .    2100003682_20
#
# [364967 rows x 105 columns]

# %%
df_zmm059_2022_2025.sample(5, random_state=5)
# Out:
#         Документ_закупки  Зп_Поз Индикатор удаления неполн.      Материал  \
# 597206      3.100013e+09     100                NaN     NaN  4500179371.0
# 48863                NaN       0                NaN     NaN           NaN
# 395556               NaN       0                NaN     NaN           NaN
# 310044      3.100007e+09    1690                NaN     NaN  4500376234.0
# 131412      3.100002e+09      90                NaN     NaN  4500075670.0
#
#             Заявка  Позиция заявки        Запрос  Позиция.1  \
# 597206  2200003311              40  6.000005e+09        100
# 48863   2200003470            1060           NaN          0
# 395556  9900002686             900           NaN          0
# 310044  2200005999              30           NaN          0
# 131412  2200000611             570           NaN          0
#
#         Долгосрочный договор  ...  Телефон  Обозначение вида материал  \
# 597206          4.600007e+09  ...      NaN  IC İnşaat Proje Malzemesi
# 48863                    NaN  ...      NaN                        NaN
# 395556                   NaN  ...      NaN                        NaN
# 310044                   NaN  ...      NaN  IC İnşaat Proje Malzemesi
# 131412          4.600001e+09  ...      NaN  IC İnşaat проект.материал
#
#         Группа закупок.2 Название ГрЗакупок.2 Затребовал  \
# 597206               NaN                  NaN        NaN
# 48863                NaN                  NaN        NaN
# 395556               NaN                  NaN        NaN
# 310044               NaN                  NaN        NaN
# 131412               NaN                  NaN        NaN
#
#        Количество во Внутреннем заказе  Единица измерения  № комиссии  \
# 597206                           0,000                NaN    AK-C-381
# 48863                            0,000                NaN         NaN
# 395556                           0,000                NaN         NaN
# 310044                           0,000                NaN   ICEND2023
# 131412                           0,000                NaN  AK-NP-1410
#
#          № ЗП в 1С         B3-B3POZ
# 597206    AK-C-381    2200003311_40
# 48863         EBAN  2200003470_1060
# 395556        EBAN   9900002686_900
# 310044   ICEND2023    2200005999_30
# 131412  AK-NP-1410   2200000611_570
#
# [5 rows x 105 columns]

# %%
# Sütunları silme
df_zmm059_2022_2025_sutunsuz = df_zmm059_2022_2025.drop(columns=["Запрос", "Позиция.1","Долгосрочный договор",
"Позиция ОснДоговора","TR Наименование","RU Наименование","Номер проекта в SAS",
 "Обозначение ВидДокум","Условие платежа","Срок платежа","Задержка","Вид материала",
"ДоговорнКоличество","Номенклатура по договору", "Наименование номенклатуры по договору",
"Сумма договору", "Договорная цена нетто","Имя клиента","Дата доставки во Внутреннем заказ",
 "Дата заявки","PR / GR (%)","PR / PO (%)","Вид документа","Внутр. заказ заводу-изготовителю",
  "Автор ЗП в 1С" ,"Тип создания","Склад" ,"Обозначение склада","Requester" ,"Групповой номер",
    "Телефон", "Обозначение вида материал" ,"Группа закупок",
 "Затребовал","Количество во Внутреннем заказе","Единица измерения","№ комиссии" ,
 "№ ЗП в 1С" ])

# %%
df_zmm059_2022_2025_sutunsuz.sample(5, random_state=6)
# Out:
#         Документ_закупки  Зп_Поз Индикатор удаления неполн.      Материал  \
# 595301      3.100013e+09      30                NaN     NaN  4500361846.0
# 450697      3.100009e+09    3940                NaN     NaN    4500386626
# 145168      3.100003e+09      40                NaN     NaN  4500080447.0
# 579404      3.100012e+09    4040                NaN     NaN  4500417811.0
# 463050      3.100010e+09     680                NaN     NaN    4500316230
#
#             Заявка  Позиция заявки                         Материалы тур.  \
# 595301  9900000973             370  AKU.0120.18UUB.0.KM.LC0001.18UUB-B1-3
# 450697  9900001413            4050       AKU.0120.10UJA.0.KM.LC0022.B5-61
# 145168  2200002702              10                KAUÇUK MANŞON DN 315 MM
# 579404  9900002531            3860                                    NaN
# 463050  9900000360             630       AKU.0120.10UJA.0.KM.LC0112.B4-43
#
#                                Материалы анг.  \
# 595301  AKU.0120.18UUB.0.KM.LC0001.18UUB-B1-3
# 450697       AKU.0120.10UJA.0.KM.LC0022.B5-61
# 145168                RUBBER SLEEVE DN 315 MM
# 579404     AKU.0120.00USY.0.KM.LC0032 Vb1-309
# 463050       AKU.0120.10UJA.0.KM.LC0112.B4-43
#
#                 Инвентарный номер в SAS  ... Количество по счету.2  \
# 595301  AKU.0503.18UUB.0.KM.LC0001(C02)  ...                   NaN
# 450697  AKU.0120.10UJA.0.KM.LC0022(C01)  ...                   NaN
# 145168  AKU.1016.40UGT.0.AS.TB0003(C02)  ...                   NaN
# 579404  AKU.0120.00USY.0.KM.LC0032(C01)  ...                   NaN
# 463050  AKU.0120.10UJA.0.KM.LC0112(C02)  ...                   NaN
#
#        Inventory number Комментарии инициатора заказа  \
# 595301              NaN                           NaN
# 450697              NaN                           NaN
# 145168              NaN                           NaN
# 579404              NaN                           NaN
# 463050              NaN                           NaN
#
#        Значок "поставка завершена"  Дата контракта  \
# 595301                           X             NaN
# 450697                           X             NaN
# 145168                           X      10.08.2022
# 579404                           X             NaN
# 463050                           X             NaN
#
#        Дата вступления в силу контракта Дата окончания действия договора  \
# 595301                              NaN                              NaN
# 450697                              NaN                              NaN
# 145168                       10.08.2022                       31.12.9999
# 579404                              NaN                              NaN
# 463050                              NaN                              NaN
#
#        Группа закупок.2 Название ГрЗакупок.2         B3-B3POZ
# 595301              NaN                  NaN   9900000973_370
# 450697              NaN                  NaN  9900001413_4050
# 145168              NaN                  NaN    2200002702_10
# 579404              NaN                  NaN  9900002531_3860
# 463050              NaN                  NaN   9900000360_630
#
# [5 rows x 67 columns]

# %%
# XLSX formatında kaydetme
df_zmm059_2022_2025_sutunsuz.to_excel("zmm059_2022_2025_temiz.xlsx", index=False)
df_zmm059_2022_2025_sutunsuz.to_csv("zmm059_2022_2025_temizsutunsuz.csv", index=False)

# %%
from google.colab import files

# Dosyayı indir
files.download("zmm059_2022_2025_temiz.xlsx")
files.download("zmm059_2022_2025_temizsutunsuz.csv")
